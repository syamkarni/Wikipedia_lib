# %%
# %pip install wikipedia
# %pip install pandas
import wikipedia as wk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
print(wk.search("IIT Madras"))
# Out:
# ['IIT Madras', 'Indian Institutes of Technology', 'Joint Entrance Examination – Advanced', 'IIT Tirupati', 'Inter IIT Sports Meet', 'IIT Palakkad', 'BharOS', 'Department of Management Studies IIT Madras', 'Ashok Leyland', 'Vineeta Singh']

# %%
print(wk.search("IIT Madras", results=2))
# Out:
# ['IIT Madras', 'Indian Institutes of Technology']

# %%
print(wk.summary("SRMIST"))
# Out:
# SRM Institute of Science and Technology (SRMIST), formerly SRM University, is a private deemed university, located in Kattankulathur, Chengalpattu (near Chennai), Tamil Nadu, India. Founded in 1985 as SRM Engineering College in Kattankulathur, it gained the deemed status in 2002. SRM Institute of Science and Technology includes six campuses, four in Tamil Nadu — Kattankulathur, Ramapuram and Vadapalani, and Tiruchirappalli, one in Amaravati, Andhra Pradesh and one in NCR Delhi.

# %%
print(wk.summary("SRMIST",sentences=2))
# Out:
# SRM Institute of Science and Technology (SRMIST), formerly SRM University, is a private deemed university, located in Kattankulathur, Chengalpattu (near Chennai), Tamil Nadu, India. Founded in 1985 as SRM Engineering College in Kattankulathur, it gained the deemed status in 2002.

# %%
full_page=wk.page("Chennai")
print(full_page.content)
# Out:
# Chennai ( , Tamil: [ˈt͡ɕenːaɪ̯], IAST: Cennaī), formerly known as Madras, is the capital city of Tamil Nadu, the southernmost state of India. It is the state's primate city and is located on the Coromandel Coast of the Bay of Bengal. According to the 2011 Indian census, Chennai is the sixth-most populous city in India and forms the fourth-most populous urban agglomeration. Incorporated in 1866, the Greater Chennai Corporation is the oldest municipal corporation of India and the second oldest in the world after London.
# ...

# %%
print(full_page.url)
# Out:
# https://en.wikipedia.org/wiki/Chennai

# %%
print(full_page.title)
# Out:
# Chennai

# %%
print(full_page.references)
# Out:
# ['http://www.chennaicorporation.gov.in/', 'http://www.historytoday.com/thomas-r-metcalfe/tradition-created-indo-saracenic-architecture-under-raj', 'http://www.higman.de/Henry%20Irwin/indo-saracenic.htm', 'http://www.cmdachennai.gov.in/pdfs/seminar_heritage_buildings/Indo_Saracenic_Architecture_in_Chennai.pdf', 'http://www.censusindia.gov.in/2011-prov-results/paper2/data_files/India2/Table_2_PR_Cities_1Lakh_and_Above.pdf', 'https://books.google.com/books?id=LnflUVu0w2QC', 'https://books.google.com/books?id=ws6om7JHZ-sC', 'http://madrasmusings.com/Vol%2018%20No%2012/parsis_of_madras.html', 'http://www.hindu.com/businessline/2000/12/18/stories/101872mz.htm', 'http://madrasmusings.com/Vol%2020%20No%2012/the-anglo-indians-of-madras.html', 'http://madrasmusings.com/Vol%2019%20No%2011/the-punjabis-of-chennai.html', 'http://www.censusindia.gov.in/2011census/C-01.html', 'https://books.google.com/books?id=Q3EsA2NooW4C', 'http://www.chennaisangamam.com/', 'http://www.chennai.org.uk/beaches/elli
# ...

# %%
print(full_page.images[0])
# Out:
# https://upload.wikimedia.org/wikipedia/commons/7/72/ALCOB_Ashok_Leyland_Corporate_Building_in_Guindy%2C_Chennai.jpg

# %%
# %pip install lxml
html=wk.page("Indian Institute of Technology Madras").html().encode("UTF-8")

import pandas as pd
df=pd.read_html(html)[6]

df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 4.5 MB 6.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
#     0                                                  1
# 0 NaN  This article's list of alumni may not follow W...
